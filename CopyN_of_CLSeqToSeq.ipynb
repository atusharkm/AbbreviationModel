# %% [markdown]
# <a href="https://colab.research.google.com/github/atusharkm/AbbreviationModel/blob/main/CopyN_of_CLSeqToSeq.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras

# %%
batch_size = 20  # Batch size for training.
epochs = 50  # Number of epochs to train for.
latent_dim = 256  # Latent dimensionality of the encoding space.
num_samples = 10000  # Number of samples to train on.
# Path to the data txt file on disk.
data_path = "TrainG.txt"

# %%
# Vectorize the data.
input_texts = []
target_texts = []
input_characters = set()
target_characters = set()
with open(data_path, "r", encoding="utf-8") as f:
    lines = f.read().split("\n")
for line in lines[: min(num_samples, len(lines) - 1)]:
    input_text, target_text= line.split("-")
    # We use "tab" as the "start sequence" character
    # for the targets, and "\n" as "end sequence" character.
    target_text = "\t" + target_text + "\n"
    input_texts.append(input_text)
    target_texts.append(target_text)
    for char in input_text:
        if char not in input_characters:
            input_characters.add(char)
    for char in target_text:
        if char not in target_characters:
            target_characters.add(char)

input_characters = sorted(list(input_characters))
target_characters = sorted(list(target_characters))
num_encoder_tokens = len(input_characters)
num_decoder_tokens = len(target_characters)
max_encoder_seq_length = max([len(txt) for txt in input_texts])
max_decoder_seq_length = max([len(txt) for txt in target_texts])

print("Number of samples:", len(input_texts))
print("Number of unique input tokens:", num_encoder_tokens)
print("Number of unique output tokens:", num_decoder_tokens)
print("Max sequence length for inputs:", max_encoder_seq_length)
print("Max sequence length for outputs:", max_decoder_seq_length)

input_token_index = dict([(char, i) for i, char in enumerate(input_characters)])
target_token_index = dict([(char, i) for i, char in enumerate(target_characters)])

encoder_input_data = np.zeros(
    (len(input_texts), max_encoder_seq_length, num_encoder_tokens), dtype="float32"
)
decoder_input_data = np.zeros(
    (len(input_texts), max_decoder_seq_length, num_decoder_tokens), dtype="float32"
)
decoder_target_data = np.zeros(
    (len(input_texts), max_decoder_seq_length, num_decoder_tokens), dtype="float32"
)

for i, (input_text, target_text) in enumerate(zip(input_texts, target_texts)):
    for t, char in enumerate(input_text):
        encoder_input_data[i, t, input_token_index[char]] = 1.0
    encoder_input_data[i, t + 1 :, input_token_index[" "]] = 1.0
    for t, char in enumerate(target_text):
        # decoder_target_data is ahead of decoder_input_data by one timestep
        decoder_input_data[i, t, target_token_index[char]] = 1.0
        if t > 0:
            # decoder_target_data will be ahead by one timestep
            # and will not include the start character.
            decoder_target_data[i, t - 1, target_token_index[char]] = 1.0
    decoder_input_data[i, t + 1 :, target_token_index[" "]] = 1.0
    decoder_target_data[i, t:, target_token_index[" "]] = 1.0
# Out:
# Number of samples: 599
# Number of unique input tokens: 27
# Number of unique output tokens: 28
# Max sequence length for inputs: 15
# Max sequence length for outputs: 19

# %%
# Define an input sequence and process it.
encoder_inputs = keras.Input(shape=(None, num_encoder_tokens))
encoder = keras.layers.LSTM(latent_dim, return_state=True)
encoder_outputs, state_h, state_c = encoder(encoder_inputs)

# We discard `encoder_outputs` and only keep the states.
encoder_states = [state_h, state_c]

# Set up the decoder, using `encoder_states` as initial state.
decoder_inputs = keras.Input(shape=(None, num_decoder_tokens))

# We set up our decoder to return full output sequences,
# and to return internal states as well. We don't use the
# return states in the training model, but we will use them in inference.
decoder_lstm = keras.layers.LSTM(latent_dim, return_sequences=True, return_state=True)
decoder_outputs, _, _ = decoder_lstm(decoder_inputs, initial_state=encoder_states)
decoder_dense = keras.layers.Dense(num_decoder_tokens, activation="softmax")
decoder_outputs = decoder_dense(decoder_outputs)

# Define the model that will turn
# `encoder_input_data` & `decoder_input_data` into `decoder_target_data`
model = keras.Model([encoder_inputs, decoder_inputs], decoder_outputs)

# %%
model.compile(
    optimizer="rmsprop", loss="categorical_crossentropy", metrics=["accuracy"]
)
model.fit(
    [encoder_input_data, decoder_input_data],
    decoder_target_data,
    batch_size=batch_size,
    epochs=epochs,
    validation_split=0.2,
)
# Save model
model.save("s2snv1")
# Out:
# Epoch 1/50
# 24/24 [==============================] - 7s 135ms/step - loss: 1.9703 - accuracy: 0.5096 - val_loss: 1.7689 - val_accuracy: 0.5390
# Epoch 2/50
# 24/24 [==============================] - 2s 101ms/step - loss: 1.6470 - accuracy: 0.5362 - val_loss: 1.5670 - val_accuracy: 0.5377
# Epoch 3/50
# 24/24 [==============================] - 2s 102ms/step - loss: 1.6059 - accuracy: 0.5442 - val_loss: 1.5552 - val_accuracy: 0.5399
# Epoch 4/50
# 24/24 [==============================] - 2s 101ms/step - loss: 1.5365 - accuracy: 0.5559 - val_loss: 1.4781 - val_accuracy: 0.5557
# Epoch 5/50
# 24/24 [==============================] - 2s 102ms/step - loss: 1.4880 - accuracy: 0.5699 - val_loss: 1.4284 - val_accuracy: 0.5794
# Epoch 6/50
# 24/24 [==============================] - 2s 101ms/step - loss: 1.4346 - accuracy: 0.5776 - val_loss: 1.3884 - val_accuracy: 0.5978
# Epoch 7/50
# 24/24 [==============================] - 2s 103ms/step - loss: 1.3884 - accuracy: 0.5921 - val_loss: 1.3557 - val_accuracy: 0.6132
# Epoch 8/50
# 24/24 [==============================] - 2s 101ms/step - loss: 1.3443 - accuracy: 0.6093 - val_loss: 1.2549 - val_accuracy: 0.6452
# Epoch 9/50
# 24/24 [==============================] - 2s 104ms/step - loss: 1.2614 - accuracy: 0.6300 - val_loss: 1.2449 - val_accuracy: 0.6434
# Epoch 10/50
# 24/24 [==============================] - 2s 101ms/step - loss: 1.1836 - accuracy: 0.6528 - val_loss: 1.0632 - val_accuracy: 0.6763
# Epoch 11/50
# 24/24 [==============================] - 2s 101ms/step - loss: 1.1068 - accuracy: 0.6703 - val_loss: 0.9965 - val_accuracy: 0.6873
# Epoch 12/50
# 24/24 [==============================] - 2s 101ms/step - loss: 1.0294 - accuracy: 0.6917 - val_loss: 0.8862 - val_accuracy: 0.7539
# Epoch 13/50
# 24/24 [==============================] - 2s 102ms/step - loss: 0.9416 - accuracy: 0.7232 - val_loss: 0.8346 - val_accuracy: 0.7579
# Epoch 14/50
# 24/24 [==============================] - 2s 99ms/step - loss: 0.8623 - accuracy: 0.7454 - val_loss: 0.8180 - val_accuracy: 0.7596
# Epoch 15/50
# 24/24 [==============================] - 2s 101ms/step - loss: 0.7821 - accuracy: 0.7668 - val_loss: 0.7269 - val_accuracy: 0.7974
# Epoch 16/50
# 24/24 [==============================] - 2s 101ms/step - loss: 0.7087 - accuracy: 0.7875 - val_loss: 0.6741 - val_accuracy: 0.8272
# Epoch 17/50
# 24/24 [==============================] - 2s 102ms/step - loss: 0.6462 - accuracy: 0.8091 - val_loss: 0.5937 - val_accuracy: 0.8526
# Epoch 18/50
# 24/24 [==============================] - 2s 101ms/step - loss: 0.5629 - accuracy: 0.8327 - val_loss: 0.5581 - val_accuracy: 0.8566
# Epoch 19/50
# 24/24 [==============================] - 2s 103ms/step - loss: 0.5131 - accuracy: 0.8512 - val_loss: 0.5216 - val_accuracy: 0.8706
# Epoch 20/50
# 24/24 [==============================] - 2s 102ms/step - loss: 0.4466 - accuracy: 0.8772 - val_loss: 0.4695 - val_accuracy: 0.8890
# Epoch 21/50
# 24/24 [==============================] - 2s 101ms/step - loss: 0.3990 - accuracy: 0.8918 - val_loss: 0.4344 - val_accuracy: 0.9070
# Epoch 22/50
# 24/24 [==============================] - 2s 101ms/step - loss: 0.3616 - accuracy: 0.9012 - val_loss: 0.4006 - val_accuracy: 0.9026
# Epoch 23/50
# 24/24 [==============================] - 2s 102ms/step - loss: 0.2967 - accuracy: 0.9240 - val_loss: 0.4124 - val_accuracy: 0.9009
# Epoch 24/50
# 24/24 [==============================] - 2s 101ms/step - loss: 0.2795 - accuracy: 0.9270 - val_loss: 0.3521 - val_accuracy: 0.9259
# Epoch 25/50
# 24/24 [==============================] - 2s 103ms/step - loss: 0.2156 - accuracy: 0.9493 - val_loss: 0.4028 - val_accuracy: 0.9022
# Epoch 26/50
# 24/24 [==============================] - 2s 103ms/step - loss: 0.2081 - accuracy: 0.9515 - val_loss: 0.3486 - val_accuracy: 0.9246
# Epoch 27/50
# 24/24 [==============================] - 2s 104ms/step - loss: 0.1853 - accuracy: 0.9565 - val_loss: 0.3179 - val_accuracy: 0.9320
# Epoch 28/50
# 24/24 [==============================] - 2s 103ms/step - loss: 0.1501 - accuracy: 0.9648 - val_loss: 0.3093 - val_accuracy: 0.9342
# Epoch 29/50
# 24/24 [==============================] - 3s 105ms/step - loss: 0.1345 - accuracy: 0.9698 - val_loss: 0.3188 - val_accuracy: 0.9311
# Epoch 30/50
# 24/24 [==============================] - 3s 104ms/step - loss: 0.1168 - accuracy: 0.9755 - val_loss: 0.3070 - val_accuracy: 0.9342
# Epoch 31/50
# 24/24 [==============================] - 3s 105ms/step - loss: 0.1166 - accuracy: 0.9743 - val_loss: 0.2877 - val_accuracy: 0.9452
# Epoch 32/50
# 24/24 [==============================] - 3s 105ms/step - loss: 0.0946 - accuracy: 0.9798 - val_loss: 0.3327 - val_accuracy: 0.9329
# Epoch 33/50
# 24/24 [==============================] - 2s 104ms/step - loss: 0.0782 - accuracy: 0.9838 - val_loss: 0.3082 - val_accuracy: 0.9443
# Epoch 34/50
# 24/24 [==============================] - 2s 102ms/step - loss: 0.0838 - accuracy: 0.9806 - val_loss: 0.3011 - val_accuracy: 0.9368
# Epoch 35/50
# 24/24 [==============================] - 2s 100ms/step - loss: 0.0698 - accuracy: 0.9832 - val_loss: 0.2805 - val_accuracy: 0.9456
# Epoch 36/50
# 24/24 [==============================] - 2s 100ms/step - loss: 0.0543 - accuracy: 0.9896 - val_loss: 0.3143 - val_accuracy: 0.9452
# Epoch 37/50
# 24/24 [==============================] - 2s 101ms/step - loss: 0.0548 - accuracy: 0.9880 - val_loss: 0.2941 - val_accuracy: 0.9491
# Epoch 38/50
# 24/24 [==============================] - 2s 102ms/step - loss: 0.0651 - accuracy: 0.9845 - val_loss: 0.3394 - val_accuracy: 0.9373
# Epoch 39/50
# 24/24 [==============================] - 2s 103ms/step - loss: 0.0401 - accuracy: 0.9914 - val_loss: 0.3122 - val_accuracy: 0.9487
# Epoch 40/50
# 24/24 [==============================] - 2s 102ms/step - loss: 0.0448 - accuracy: 0.9898 - val_loss: 0.5024 - val_accuracy: 0.8895
# Epoch 41/50
# 24/24 [==============================] - 2s 102ms/step - loss: 0.0580 - accuracy: 0.9860 - val_loss: 0.2918 - val_accuracy: 0.9474
# Epoch 42/50
# 24/24 [==============================] - 2s 101ms/step - loss: 0.0393 - accuracy: 0.9902 - val_loss: 0.3248 - val_accuracy: 0.9425
# Epoch 43/50
# 24/24 [==============================] - 2s 102ms/step - loss: 0.0602 - accuracy: 0.9852 - val_loss: 0.2811 - val_accuracy: 0.9496
# Epoch 44/50
# 24/24 [==============================] - 2s 102ms/step - loss: 0.0263 - accuracy: 0.9940 - val_loss: 0.3006 - val_accuracy: 0.9487
# Epoch 45/50
# 24/24 [==============================] - 2s 101ms/step - loss: 0.0481 - accuracy: 0.9878 - val_loss: 0.2928 - val_accuracy: 0.9425
# Epoch 46/50
# 24/24 [==============================] - 2s 101ms/step - loss: 0.0381 - accuracy: 0.9889 - val_loss: 0.3145 - val_accuracy: 0.9443
# Epoch 47/50
# 24/24 [==============================] - 2s 102ms/step - loss: 0.0248 - accuracy: 0.9940 - val_loss: 0.2827 - val_accuracy: 0.9496
# Epoch 48/50
# 24/24 [==============================] - 2s 101ms/step - loss: 0.0396 - accuracy: 0.9901 - val_loss: 0.3075 - val_accuracy: 0.9513
# Epoch 49/50
# 24/24 [==============================] - 2s 102ms/step - loss: 0.0358 - accuracy: 0.9899 - val_loss: 0.2934 - val_accuracy: 0.9482
# Epoch 50/50
# 24/24 [==============================] - 2s 104ms/step - loss: 0.0278 - accuracy: 0.9940 - val_loss: 0.3164 - val_accuracy: 0.9399
# WARNING:absl:Found untraced functions such as lstm_cell_4_layer_call_and_return_conditional_losses, lstm_cell_4_layer_call_fn, lstm_cell_5_layer_call_and_return_conditional_losses, lstm_cell_5_layer_call_fn, lstm_cell_4_layer_call_fn while saving (showing 5 of 10). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: s2snv1/assets
# INFO:tensorflow:Assets written to: s2snv1/assets

# %%
# Define sampling models
# Restore the model and construct the encoder and decoder.
model = keras.models.load_model("s2snv1")

encoder_inputs = model.input[0]  # input_1
encoder_outputs, state_h_enc, state_c_enc = model.layers[2].output  # lstm_1
encoder_states = [state_h_enc, state_c_enc]
encoder_model = keras.Model(encoder_inputs, encoder_states)

decoder_inputs = model.input[1]  # input_2
decoder_state_input_h = keras.Input(shape=(latent_dim,), name="input_3")
decoder_state_input_c = keras.Input(shape=(latent_dim,), name="input_4")
decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]
decoder_lstm = model.layers[3]
decoder_outputs, state_h_dec, state_c_dec = decoder_lstm(
    decoder_inputs, initial_state=decoder_states_inputs
)
decoder_states = [state_h_dec, state_c_dec]
decoder_dense = model.layers[4]
decoder_outputs = decoder_dense(decoder_outputs)
decoder_model = keras.Model(
    [decoder_inputs] + decoder_states_inputs, [decoder_outputs] + decoder_states
)

# Reverse-lookup token index to decode sequences back to
# something readable.
reverse_input_char_index = dict((i, char) for char, i in input_token_index.items())
reverse_target_char_index = dict((i, char) for char, i in target_token_index.items())


def decode_sequence(input_seq):
    # Encode the input as state vectors.
    states_value = encoder_model.predict(input_seq)

    # Generate empty target sequence of length 1.
    target_seq = np.zeros((1, 1, num_decoder_tokens))
    # Populate the first character of target sequence with the start character.
    target_seq[0, 0, target_token_index["\t"]] = 1.0

    # Sampling loop for a batch of sequences
    # (to simplify, here we assume a batch of size 1).
    stop_condition = False
    decoded_sentence = ""
    while not stop_condition:
        output_tokens, h, c = decoder_model.predict([target_seq] + states_value)

        # Sample a token
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_char = reverse_target_char_index[sampled_token_index]
        decoded_sentence += sampled_char

        # Exit condition: either hit max length
        # or find stop character.
        if sampled_char == "\n" or len(decoded_sentence) > max_decoder_seq_length:
            stop_condition = True

        # Update the target sequence (of length 1).
        target_seq = np.zeros((1, 1, num_decoder_tokens))
        target_seq[0, 0, sampled_token_index] = 1.0

        # Update states
        states_value = [h, c]
    return decoded_sentence
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-4cda7a53d4ca> in <module>()
#      20 decoder_outputs = decoder_dense(decoder_outputs)
#      21 decoder_model = keras.Model(
# ---> 22     [decoder_inputs] + decoder_states_inputs, [decoder_outputs] + decoder_states
#      23 )
#      24
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/training/tracking/base.py in _method_wrapper(self, *args, **kwargs)
#     520     self._self_setattr_tracking = False  # pylint: disable=protected-access
#     521     try:
# --> 522       result = method(self, *args, **kwargs)
#     523     finally:
#     524       self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/functional.py in __init__(self, inputs, outputs, name, trainable, **kwargs)
#     113     generic_utils.validate_kwargs(kwargs, {})
#     114     super(Functional, self).__init__(name=name, trainable=trainable)
# --> 115     self._init_graph_network(inputs, outputs)
#     116
#     117   @trackable.no_automatic_dependency_tracking
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/training/tracking/base.py in _method_wrapper(self, *args, **kwargs)
#     520     self._self_setattr_tracking = False  # pylint: disable=protected-access
#     521     try:
# --> 522       result = method(self, *args, **kwargs)
#     523     finally:
#     524       self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/functional.py in _init_graph_network(self, inputs, outputs)
#     197     # Keep track of the network's nodes and layers.
#     198     nodes, nodes_by_depth, layers, _ = _map_graph_network(
# --> 199         self.inputs, self.outputs)
#     200     self._network_nodes = nodes
#     201     self._nodes_by_depth = nodes_by_depth
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/functional.py in _map_graph_network(inputs, outputs)
#     999     if all_names.count(name) != 1:
#    1000       raise ValueError('The name "' + name + '" is used ' +
# -> 1001                        str(all_names.count(name)) + ' times in the model. '
#    1002                        'All layer names should be unique.')
#    1003   return network_nodes, nodes_by_depth, layers, layers_by_depth
#
# ValueError: The name "input_4" is used 2 times in the model. All layer names should be unique.

# %%
# %%time

for seq_index in range(1,200):
    # Take one sequence (part of the training set)
    # for trying out decoding.
    input_seq = encoder_input_data[seq_index : seq_index + 1]
    decoded_sentence = decode_sequence(input_seq)
    print("-")
    print("Input sentence:", input_texts[seq_index])
    print("Decoded sentence:", decoded_sentence)
# Out:
# -
# Input sentence: mmer
# Decoded sentence: member
#
# -
# Input sentence: membr
# Decoded sentence: member
#
# -
# Input sentence: mmber
# Decoded sentence: member
#
# -
# Input sentence: membe
# Decoded sentence: member
#
# -
# Input sentence: meber
# Decoded sentence: member
#
# -
# Input sentence: memer
# Decoded sentence: member
#
# -
# Input sentence: member
# Decoded sentence: member
#
# -
# Input sentence: adrs
# Decoded sentence: address
#
# -
# Input sentence: addrs
# Decoded sentence: address
#
# -
# Input sentence: addrss
# Decoded sentence: address
#
# -
# Input sentence: adres
# Decoded sentence: address
#
# -
# Input sentence: adres
# Decoded sentence: address
#
# -
# Input sentence: addrss
# Decoded sentence: address
#
# -
# Input sentence: addres
# Decoded sentence: address
#
# -
# Input sentence: address
# Decoded sentence: address
#
# -
# Input sentence: emaladrs
# Decoded sentence: email address
#
# -
# Input sentence: emladdrs
# Decoded sentence: email address
#
# -
# Input sentence: emladrs
# Decoded sentence: email address
#
# -
# Input sentence: emladres
# Decoded sentence: email address
#
# -
# Input sentence: emailadrs
# Decoded sentence: email address
#
# -
# Input sentence: emladdress
# Decoded sentence: email address
#
# -
# Input sentence: emiladdress
# Decoded sentence: email address
#
# -
# Input sentence: email address
# Decoded sentence: email address
#
# -
# Input sentence: pstl
# Decoded sentence: postal
#
# -
# Input sentence: postl
# Decoded sentence: postal zip
#
# -
# Input sentence: posta
# Decoded sentence: postal
#
# -
# Input sentence: pstal
# Decoded sentence: postal zip
#
# -
# Input sentence: postal
# Decoded sentence: postal zip
#
# -
# Input sentence: pstladdrss
# Decoded sentence: postal address
#
# -
# Input sentence: postladdrss
# Decoded sentence: postal address
#
# -
# Input sentence: postaaddrss
# Decoded sentence: postal address
#
# -
# Input sentence: pstaladdrss
# Decoded sentence: postal address
#
# -
# Input sentence: pstladrss
# Decoded sentence: postal address
#
# -
# Input sentence: postladrss
# Decoded sentence: postal address
#
# -
# Input sentence: postaadrss
# Decoded sentence: postal address
#
# -
# Input sentence: pstaladrss
# Decoded sentence: postal address
#
# -
# Input sentence: pstladdrs
# Decoded sentence: postal address
#
# -
# Input sentence: postladdrs
# Decoded sentence: postal address
#
# -
# Input sentence: postaaddrs
# Decoded sentence: postal address
#
# -
# Input sentence: pstaladdrs
# Decoded sentence: postal address
#
# -
# Input sentence: postal address
# Decoded sentence: postal address
#
# -
# Input sentence: infrmtn
# Decoded sentence: information
#
# -
# Input sentence: infrmtion
# Decoded sentence: information
#
# -
# Input sentence: infrmtin
# Decoded sentence: information
#
# -
# Input sentence: informtn
# Decoded sentence: information
#
# -
# Input sentence: information
# Decoded sentence: information
#
# -
# Input sentence: new info
# Decoded sentence: new information
#
# -
# Input sentence: new information
# Decoded sentence: new information
#
# -
# Input sentence: info
# Decoded sentence: information
#
# -
# Input sentence: zp
# Decoded sentence: zip
#
# -
# Input sentence: pstl zp
# Decoded sentence: postal address
#
# -
# Input sentence: postal zip
# Decoded sentence: postal address
#
# -
# Input sentence: zpcd
# Decoded sentence: birest
#
# -
# Input sentence: cd
# Decoded sentence: code
#
# -
# Input sentence: cod
# Decoded sentence: code
#
# -
# Input sentence: cde
# Decoded sentence: code
#
# -
# Input sentence: code
# Decoded sentence: code
#
# -
# Input sentence: intrst
# Decoded sentence: interest
#
# -
# Input sentence: interst
# Decoded sentence: interest
#
# -
# Input sentence: itrst
# Decoded sentence: interest
#
# -
# Input sentence: intrest
# Decoded sentence: interest
#
# -
# Input sentence: iterest
# Decoded sentence: interest
#
# -
# Input sentence: interest
# Decoded sentence: interest
#
# -
# Input sentence: amnt
# Decoded sentence: amount
#
# -
# Input sentence: aount
# Decoded sentence: amount
#
# -
# Input sentence: amont
# Decoded sentence: amount
#
# -
# Input sentence: amt
# Decoded sentence: amount
#
# -
# Input sentence: amount
# Decoded sentence: amount
#
# -
# Input sentence: tlphn
# Decoded sentence: telephone
#
# -
# Input sentence: telephn
# Decoded sentence: telephone
#
# -
# Input sentence: tlphon
# Decoded sentence: telephone
#
# -
# Input sentence: telphn
# Decoded sentence: telephone
#
# -
# Input sentence: telephon
# Decoded sentence: telephone
#
# -
# Input sentence: tlphne
# Decoded sentence: telephone
#
# -
# Input sentence: telephone
# Decoded sentence: telephone
#
# -
# Input sentence: phn
# Decoded sentence: phone
#
# -
# Input sentence: phon
# Decoded sentence: phone
#
# -
# Input sentence: phne
# Decoded sentence: phone
#
# -
# Input sentence: phone
# Decoded sentence: phone
#
# -
# Input sentence: tx
# Decoded sentence: tax
#
# -
# Input sentence: incm
# Decoded sentence: income
#
# -
# Input sentence: incme
# Decoded sentence: income
#
# -
# Input sentence: incom
# Decoded sentence: income
#
# -
# Input sentence: income
# Decoded sentence: income
#
# -
# Input sentence: incmtx
# Decoded sentence: income tax
#
# -
# Input sentence: incomtx
# Decoded sentence: income tax
#
# -
# Input sentence: incmtax
# Decoded sentence: income tax
#
# -
# Input sentence: income tax
# Decoded sentence: income tax
#
# -
# Input sentence: rvnue
# Decoded sentence: revenue
#
# -
# Input sentence: rvnu
# Decoded sentence: revenue
#
# -
# Input sentence: revnu
# Decoded sentence: revenue
#
# -
# Input sentence: revenu
# Decoded sentence: revenue
#
# -
# Input sentence: revnue
# Decoded sentence: revenue
#
# -
# Input sentence: revenue
# Decoded sentence: revenue
#
# -
# Input sentence: eml
# Decoded sentence: email
#
# -
# Input sentence: emal
# Decoded sentence: email
#
# -
# Input sentence: emil
# Decoded sentence: email
#
# -
# Input sentence: eail
# Decoded sentence: email
#
# -
# Input sentence: email
# Decoded sentence: email
#
# -
# Input sentence: idnty
# Decoded sentence: identity
#
# -
# Input sentence: idntty
# Decoded sentence: identity
#
# -
# Input sentence: idntity
# Decoded sentence: identity
#
# -
# Input sentence: identy
# Decoded sentence: identity
#
# -
# Input sentence: idty
# Decoded sentence: identity
#
# -
# Input sentence: identity
# Decoded sentence: identity
#
# -
# Input sentence: srl
# Decoded sentence: serial
#
# -
# Input sentence: serl
# Decoded sentence: serial
#
# -
# Input sentence: seril
# Decoded sentence: serial
#
# -
# Input sentence: sril
# Decoded sentence: serial
#
# -
# Input sentence: serial
# Decoded sentence: serial
#
# -
# Input sentence: nbr
# Decoded sentence: number
#
# -
# Input sentence: nmbr
# Decoded sentence: number
#
# -
# Input sentence: nber
# Decoded sentence: number
#
# -
# Input sentence: nmber
# Decoded sentence: number
#
# -
# Input sentence: numbr
# Decoded sentence: number
#
# -
# Input sentence: number
# Decoded sentence: number
#
# -
# Input sentence: idntfctn
# Decoded sentence: identification
#
# -
# Input sentence: idtfiction
# Decoded sentence: identification
#
# -
# Input sentence: identfctn
# Decoded sentence: identification
#
# -
# Input sentence: identfcton
# Decoded sentence: identification
#
# -
# Input sentence: idntfcatin
# Decoded sentence: identification
#
# -
# Input sentence: idntfction
# Decoded sentence: identification
#
# -
# Input sentence: identification
# Decoded sentence: identification
#
# -
# Input sentence: brth
# Decoded sentence: birth
#
# -
# Input sentence: birt
# Decoded sentence: birth
#
# -
# Input sentence: bth
# Decoded sentence: birth
#
# -
# Input sentence: birth
# Decoded sentence: birth
#
# -
# Input sentence: dt
# Decoded sentence: date
#
# -
# Input sentence: dat
# Decoded sentence: date
#
# -
# Input sentence: dte
# Decoded sentence: date
#
# -
# Input sentence: date
# Decoded sentence: date
#
# -
# Input sentence: brthdt
# Decoded sentence: birth date
#
# -
# Input sentence: bithdte
# Decoded sentence: birth date
#
# -
# Input sentence: brthdate
# Decoded sentence: birth date
#
# -
# Input sentence: birth date
# Decoded sentence: birth
#
# -
# Input sentence: dth
# Decoded sentence: death
#
# -
# Input sentence: deth
# Decoded sentence: death
#
# -
# Input sentence: dath
# Decoded sentence: death
#
# -
# Input sentence: deat
# Decoded sentence: date
#
# -
# Input sentence: death
# Decoded sentence: death
#
# -
# Input sentence: dethdte
# Decoded sentence: death date
#
# -
# Input sentence: dthdte
# Decoded sentence: death date
#
# -
# Input sentence: death date
# Decoded sentence: death
#
# -
# Input sentence: snstve
# Decoded sentence: sensitive
#
# -
# Input sentence: senstive
# Decoded sentence: sensitive
#
# -
# Input sentence: ssitve
# Decoded sentence: sensitive
#
# -
# Input sentence: snstiv
# Decoded sentence: sensitive
#
# -
# Input sentence: senstv
# Decoded sentence: sensitive
#
# -
# Input sentence: sensitive
# Decoded sentence: sensitive
#
# -
# Input sentence: acmdtn
# Decoded sentence: accommodation
#
# -
# Input sentence: acomdtn
# Decoded sentence: accommodation
#
# -
# Input sentence: acomdaton
# Decoded sentence: accommodation
#
# -
# Input sentence: acmdaton
# Decoded sentence: accommodation
#
# -
# Input sentence: acomdtion
# Decoded sentence: accommodation
#
# -
# Input sentence: accommodation
# Decoded sentence: accommodation
#
# -
# Input sentence: acnt
# Decoded sentence: account
#
# -
# Input sentence: accnt
# Decoded sentence: account
#
# -
# Input sentence: acont
# Decoded sentence: account
#
# -
# Input sentence: acunt
# Decoded sentence: account
#
# -
# Input sentence: acont
# Decoded sentence: account
#
# -
# Input sentence: account
# Decoded sentence: account
#
# -
# Input sentence: admsion
# Decoded sentence: admission
#
# -
# Input sentence: admsn
# Decoded sentence: admission
#
# -
# Input sentence: admisn
# Decoded sentence: admission
#
# -
# Input sentence: admson
# Decoded sentence: admission
#
# -
# Input sentence: addmsn
# Decoded sentence: admission
#
# -
# Input sentence: admission
# Decoded sentence: admission
#
# -
# Input sentence: afdvt
# Decoded sentence: affidavit
#
# -
# Input sentence: afdavt
# Decoded sentence: affidavit
#
# -
# Input sentence: affdvt
# Decoded sentence: affidavit
#
# -
# Input sentence: afidvit
# Decoded sentence: affidavit
#
# -
# Input sentence: afdvit
# Decoded sentence: affidavit
#
# -
# Input sentence: affidavit
# Decoded sentence: affidavit
#
# -
# Input sentence: agncy
# Decoded sentence: agency
#
# -
# Input sentence: agcy
# Decoded sentence: agency
#
# -
# Input sentence: ancey
# Decoded sentence: agency
#
# -
# Input sentence: agnc
# Decoded sentence: agency
#
# -
# Input sentence: agency
# Decoded sentence: agency
#
# -
# Input sentence: agrmnt
# Decoded sentence: agreement
#
# -
# Input sentence: agmnt
# Decoded sentence: agreement
#
# -
# Input sentence: agrmt
# Decoded sentence: agreement
#
# -
# Input sentence: agemnt
# Decoded sentence: agreement
#
# -
# Input sentence: agrmt
# Decoded sentence: agreement
#
# -
# Input sentence: agreement
# Decoded sentence: agreement
#
# -
# Input sentence: nm
# Decoded sentence: name
#
# -
# Input sentence: nme
# Decoded sentence: name
#
# -
# Input sentence: nam
# Decoded sentence: name
#
# -
# Input sentence: name
# Decoded sentence: name
#
# -
# Input sentence: frst
# Decoded sentence: first
#
# -
# Input sentence: fst
# Decoded sentence: first
#
# -
# Input sentence: frt
# Decoded sentence: fathe
#
# -
# Input sentence: firt
# Decoded sentence: first
#
# -
# Input sentence: first
# Decoded sentence: first
#
# -
# Input sentence: lst
# Decoded sentence: last
#
# -
# Input sentence: lat
# Decoded sentence: last
#
# -
# Input sentence: frtnm
# Decoded sentence: first
#
# -
# Input sentence: frstnm
# Decoded sentence: first
#
# -
# Input sentence: frstnme
# Decoded sentence: first
#
# -
# Input sentence: fstnam
# Decoded sentence: first
#
# CPU times: user 1min 55s, sys: 1.92 s, total: 1min 57s
# Wall time: 1min 57s
