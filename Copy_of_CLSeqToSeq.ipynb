# %% [markdown]
# <a href="https://colab.research.google.com/github/atusharkm/AbbreviationModel/blob/main/Copy_of_CLSeqToSeq.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras

# %%
batch_size = 20  # Batch size for training.
epochs = 50  # Number of epochs to train for.
latent_dim = 256  # Latent dimensionality of the encoding space.
num_samples = 10000  # Number of samples to train on.
# Path to the data txt file on disk.
data_path = "TrainG.txt"

# %%
# Vectorize the data.
input_texts = []
target_texts = []
input_characters = set()
target_characters = set()
with open(data_path, "r", encoding="utf-8") as f:
    lines = f.read().split("\n")
for line in lines[: min(num_samples, len(lines) - 1)]:
    input_text, target_text= line.split("-")
    # We use "tab" as the "start sequence" character
    # for the targets, and "\n" as "end sequence" character.
    target_text = "\t" + target_text + "\n"
    input_texts.append(input_text)
    target_texts.append(target_text)
    for char in input_text:
        if char not in input_characters:
            input_characters.add(char)
    for char in target_text:
        if char not in target_characters:
            target_characters.add(char)

input_characters = sorted(list(input_characters))
target_characters = sorted(list(target_characters))
num_encoder_tokens = len(input_characters)
num_decoder_tokens = len(target_characters)
max_encoder_seq_length = max([len(txt) for txt in input_texts])
max_decoder_seq_length = max([len(txt) for txt in target_texts])

print("Number of samples:", len(input_texts))
print("Number of unique input tokens:", num_encoder_tokens)
print("Number of unique output tokens:", num_decoder_tokens)
print("Max sequence length for inputs:", max_encoder_seq_length)
print("Max sequence length for outputs:", max_decoder_seq_length)

input_token_index = dict([(char, i) for i, char in enumerate(input_characters)])
target_token_index = dict([(char, i) for i, char in enumerate(target_characters)])

encoder_input_data = np.zeros(
    (len(input_texts), max_encoder_seq_length, num_encoder_tokens), dtype="float32"
)
decoder_input_data = np.zeros(
    (len(input_texts), max_decoder_seq_length, num_decoder_tokens), dtype="float32"
)
decoder_target_data = np.zeros(
    (len(input_texts), max_decoder_seq_length, num_decoder_tokens), dtype="float32"
)

for i, (input_text, target_text) in enumerate(zip(input_texts, target_texts)):
    for t, char in enumerate(input_text):
        encoder_input_data[i, t, input_token_index[char]] = 1.0
    encoder_input_data[i, t + 1 :, input_token_index[" "]] = 1.0
    for t, char in enumerate(target_text):
        # decoder_target_data is ahead of decoder_input_data by one timestep
        decoder_input_data[i, t, target_token_index[char]] = 1.0
        if t > 0:
            # decoder_target_data will be ahead by one timestep
            # and will not include the start character.
            decoder_target_data[i, t - 1, target_token_index[char]] = 1.0
    decoder_input_data[i, t + 1 :, target_token_index[" "]] = 1.0
    decoder_target_data[i, t:, target_token_index[" "]] = 1.0
# Out:
# Number of samples: 119
# Number of unique input tokens: 24
# Number of unique output tokens: 25
# Max sequence length for inputs: 11
# Max sequence length for outputs: 17

# %%
# Define an input sequence and process it.
encoder_inputs = keras.Input(shape=(None, num_encoder_tokens))
encoder = keras.layers.LSTM(latent_dim, return_state=True)
encoder_outputs, state_h, state_c = encoder(encoder_inputs)

# We discard `encoder_outputs` and only keep the states.
encoder_states = [state_h, state_c]

# Set up the decoder, using `encoder_states` as initial state.
decoder_inputs = keras.Input(shape=(None, num_decoder_tokens))

# We set up our decoder to return full output sequences,
# and to return internal states as well. We don't use the
# return states in the training model, but we will use them in inference.
decoder_lstm = keras.layers.LSTM(latent_dim, return_sequences=True, return_state=True)
decoder_outputs, _, _ = decoder_lstm(decoder_inputs, initial_state=encoder_states)
decoder_dense = keras.layers.Dense(num_decoder_tokens, activation="softmax")
decoder_outputs = decoder_dense(decoder_outputs)

# Define the model that will turn
# `encoder_input_data` & `decoder_input_data` into `decoder_target_data`
model = keras.Model([encoder_inputs, decoder_inputs], decoder_outputs)

# %%
model.compile(
    optimizer="rmsprop", loss="categorical_crossentropy", metrics=["accuracy"]
)
model.fit(
    [encoder_input_data, decoder_input_data],
    decoder_target_data,
    batch_size=batch_size,
    epochs=epochs,
    validation_split=0.2,
)
# Save model
model.save("s2sv04")
# Out:
# Epoch 1/50
# 5/5 [==============================] - 6s 307ms/step - loss: 0.0631 - accuracy: 0.9864 - val_loss: 3.3394 - val_accuracy: 0.5637
# Epoch 2/50
# 5/5 [==============================] - 0s 89ms/step - loss: 0.0744 - accuracy: 0.9827 - val_loss: 3.0510 - val_accuracy: 0.5662
# Epoch 3/50
# 5/5 [==============================] - 0s 95ms/step - loss: 0.0562 - accuracy: 0.9845 - val_loss: 3.1191 - val_accuracy: 0.5662
# Epoch 4/50
# 5/5 [==============================] - 0s 90ms/step - loss: 0.0343 - accuracy: 0.9938 - val_loss: 3.0909 - val_accuracy: 0.5711
# Epoch 5/50
# 5/5 [==============================] - 0s 92ms/step - loss: 0.0250 - accuracy: 0.9969 - val_loss: 3.0849 - val_accuracy: 0.5686
# Epoch 6/50
# 5/5 [==============================] - 0s 90ms/step - loss: 0.0189 - accuracy: 0.9988 - val_loss: 3.0561 - val_accuracy: 0.5662
# Epoch 7/50
# 5/5 [==============================] - 0s 89ms/step - loss: 0.0151 - accuracy: 0.9994 - val_loss: 3.0557 - val_accuracy: 0.5662
# Epoch 8/50
# 5/5 [==============================] - 0s 90ms/step - loss: 0.0124 - accuracy: 0.9994 - val_loss: 3.1006 - val_accuracy: 0.5539
# Epoch 9/50
# 5/5 [==============================] - 0s 92ms/step - loss: 0.0101 - accuracy: 1.0000 - val_loss: 3.1565 - val_accuracy: 0.5490
# Epoch 10/50
# 5/5 [==============================] - 0s 93ms/step - loss: 0.0086 - accuracy: 1.0000 - val_loss: 3.2054 - val_accuracy: 0.5564
# Epoch 11/50
# 5/5 [==============================] - 0s 89ms/step - loss: 0.0074 - accuracy: 1.0000 - val_loss: 3.2430 - val_accuracy: 0.5564
# Epoch 12/50
# 5/5 [==============================] - 0s 91ms/step - loss: 0.0065 - accuracy: 1.0000 - val_loss: 3.2692 - val_accuracy: 0.5564
# Epoch 13/50
# 5/5 [==============================] - 0s 90ms/step - loss: 0.0059 - accuracy: 1.0000 - val_loss: 3.2905 - val_accuracy: 0.5539
# Epoch 14/50
# 5/5 [==============================] - 0s 93ms/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 3.3152 - val_accuracy: 0.5564
# Epoch 15/50
# 5/5 [==============================] - 0s 93ms/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 3.3493 - val_accuracy: 0.5564
# Epoch 16/50
# 5/5 [==============================] - 0s 94ms/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 3.3903 - val_accuracy: 0.5564
# Epoch 17/50
# 5/5 [==============================] - 0s 95ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 3.4308 - val_accuracy: 0.5564
# Epoch 18/50
# 5/5 [==============================] - 0s 97ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 3.4665 - val_accuracy: 0.5588
# Epoch 19/50
# 5/5 [==============================] - 0s 87ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 3.4884 - val_accuracy: 0.5588
# Epoch 20/50
# 5/5 [==============================] - 0s 90ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 3.5106 - val_accuracy: 0.5564
# Epoch 21/50
# 5/5 [==============================] - 0s 89ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 3.5357 - val_accuracy: 0.5564
# Epoch 22/50
# 5/5 [==============================] - 0s 89ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 3.5586 - val_accuracy: 0.5564
# Epoch 23/50
# 5/5 [==============================] - 0s 90ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 3.5803 - val_accuracy: 0.5564
# Epoch 24/50
# 5/5 [==============================] - 0s 90ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 3.6031 - val_accuracy: 0.5564
# Epoch 25/50
# 5/5 [==============================] - 0s 93ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 3.6238 - val_accuracy: 0.5564
# Epoch 26/50
# 5/5 [==============================] - 0s 89ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 3.6415 - val_accuracy: 0.5564
# Epoch 27/50
# 5/5 [==============================] - 0s 93ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 3.6594 - val_accuracy: 0.5564
# Epoch 28/50
# 5/5 [==============================] - 0s 86ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 3.6796 - val_accuracy: 0.5564
# Epoch 29/50
# 5/5 [==============================] - 0s 88ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 3.6957 - val_accuracy: 0.5564
# Epoch 30/50
# 5/5 [==============================] - 0s 90ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 3.7130 - val_accuracy: 0.5564
# Epoch 31/50
# 5/5 [==============================] - 0s 90ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 3.7321 - val_accuracy: 0.5539
# Epoch 32/50
# 5/5 [==============================] - 0s 89ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 3.7491 - val_accuracy: 0.5539
# Epoch 33/50
# 5/5 [==============================] - 0s 90ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 3.7648 - val_accuracy: 0.5539
# Epoch 34/50
# 5/5 [==============================] - 0s 88ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 3.7789 - val_accuracy: 0.5539
# Epoch 35/50
# 5/5 [==============================] - 0s 86ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 3.7956 - val_accuracy: 0.5515
# Epoch 36/50
# 5/5 [==============================] - 0s 92ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 3.8107 - val_accuracy: 0.5515
# Epoch 37/50
# 5/5 [==============================] - 0s 88ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 3.8254 - val_accuracy: 0.5515
# Epoch 38/50
# 5/5 [==============================] - 0s 89ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 3.8406 - val_accuracy: 0.5515
# Epoch 39/50
# 5/5 [==============================] - 0s 87ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 3.8559 - val_accuracy: 0.5515
# Epoch 40/50
# 5/5 [==============================] - 0s 92ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 3.8709 - val_accuracy: 0.5515
# Epoch 41/50
# 5/5 [==============================] - 0s 94ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 3.8857 - val_accuracy: 0.5515
# Epoch 42/50
# 5/5 [==============================] - 0s 90ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 3.8988 - val_accuracy: 0.5515
# Epoch 43/50
# 5/5 [==============================] - 0s 92ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 3.9116 - val_accuracy: 0.5515
# Epoch 44/50
# 5/5 [==============================] - 0s 89ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 3.9246 - val_accuracy: 0.5515
# Epoch 45/50
# 5/5 [==============================] - 0s 89ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 3.9341 - val_accuracy: 0.5515
# Epoch 46/50
# 5/5 [==============================] - 0s 88ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 3.9452 - val_accuracy: 0.5515
# Epoch 47/50
# 5/5 [==============================] - 0s 89ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 3.9593 - val_accuracy: 0.5515
# Epoch 48/50
# 5/5 [==============================] - 0s 85ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 3.9709 - val_accuracy: 0.5515
# Epoch 49/50
# 5/5 [==============================] - 0s 89ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 3.9825 - val_accuracy: 0.5515
# Epoch 50/50
# 5/5 [==============================] - 0s 90ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 3.9957 - val_accuracy: 0.5515
# WARNING:absl:Found untraced functions such as lstm_cell_4_layer_call_fn, lstm_cell_4_layer_call_and_return_conditional_losses, lstm_cell_5_layer_call_fn, lstm_cell_5_layer_call_and_return_conditional_losses, lstm_cell_4_layer_call_fn while saving (showing 5 of 10). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: s2sv04/assets
# INFO:tensorflow:Assets written to: s2sv04/assets

# %%
# Define sampling models
# Restore the model and construct the encoder and decoder.
model = keras.models.load_model("s2sv03")

encoder_inputs = model.input[0]  # input_1
encoder_outputs, state_h_enc, state_c_enc = model.layers[2].output  # lstm_1
encoder_states = [state_h_enc, state_c_enc]
encoder_model = keras.Model(encoder_inputs, encoder_states)

decoder_inputs = model.input[1]  # input_2
decoder_state_input_h = keras.Input(shape=(latent_dim,), name="input_3")
decoder_state_input_c = keras.Input(shape=(latent_dim,), name="input_4")
decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]
decoder_lstm = model.layers[3]
decoder_outputs, state_h_dec, state_c_dec = decoder_lstm(
    decoder_inputs, initial_state=decoder_states_inputs
)
decoder_states = [state_h_dec, state_c_dec]
decoder_dense = model.layers[4]
decoder_outputs = decoder_dense(decoder_outputs)
decoder_model = keras.Model(
    [decoder_inputs] + decoder_states_inputs, [decoder_outputs] + decoder_states
)

# Reverse-lookup token index to decode sequences back to
# something readable.
reverse_input_char_index = dict((i, char) for char, i in input_token_index.items())
reverse_target_char_index = dict((i, char) for char, i in target_token_index.items())


def decode_sequence(input_seq):
    # Encode the input as state vectors.
    states_value = encoder_model.predict(input_seq)

    # Generate empty target sequence of length 1.
    target_seq = np.zeros((1, 1, num_decoder_tokens))
    # Populate the first character of target sequence with the start character.
    target_seq[0, 0, target_token_index["\t"]] = 1.0

    # Sampling loop for a batch of sequences
    # (to simplify, here we assume a batch of size 1).
    stop_condition = False
    decoded_sentence = ""
    while not stop_condition:
        output_tokens, h, c = decoder_model.predict([target_seq] + states_value)

        # Sample a token
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_char = reverse_target_char_index[sampled_token_index]
        decoded_sentence += sampled_char

        # Exit condition: either hit max length
        # or find stop character.
        if sampled_char == "\n" or len(decoded_sentence) > max_decoder_seq_length:
            stop_condition = True

        # Update the target sequence (of length 1).
        target_seq = np.zeros((1, 1, num_decoder_tokens))
        target_seq[0, 0, sampled_token_index] = 1.0

        # Update states
        states_value = [h, c]
    return decoded_sentence

# %%
for seq_index in range(1,30):
    # Take one sequence (part of the training set)
    # for trying out decoding.
    input_seq = encoder_input_data[seq_index : seq_index + 1]
    decoded_sentence = decode_sequence(input_seq)
    print("-")
    print("Input sentence:", input_texts[seq_index])
    print("Decoded sentence:", decoded_sentence)
# Out:
# -
# Input sentence: mmer
# Decoded sentence: member
#
# -
# Input sentence: membr
# Decoded sentence: member
#
# -
# Input sentence: mmber
# Decoded sentence: member
#
# -
# Input sentence: membe
# Decoded sentence: member
#
# -
# Input sentence: meber
# Decoded sentence: member
#
# -
# Input sentence: memer
# Decoded sentence: member
#
# -
# Input sentence: adrs
# Decoded sentence: address
#
# -
# Input sentence: addrs
# Decoded sentence: address
#
# -
# Input sentence: addrss
# Decoded sentence: address
#
# -
# Input sentence: adres
# Decoded sentence: address
#
# -
# Input sentence: adres
# Decoded sentence: address
#
# -
# Input sentence: addrss
# Decoded sentence: address
#
# -
# Input sentence: addres
# Decoded sentence: address
#
# -
# Input sentence: emaladrs
# Decoded sentence: email address
#
# -
# Input sentence: emladdrs
# Decoded sentence: email address
#
# -
# Input sentence: emladrs
# Decoded sentence: email address
#
# -
# Input sentence: emladres
# Decoded sentence: email address
#
# -
# Input sentence: emailadrs
# Decoded sentence: email address
#
# -
# Input sentence: emladdress
# Decoded sentence: email address
#
# -
# Input sentence: emiladdress
# Decoded sentence: email address
#
# -
# Input sentence: pstl
# Decoded sentence: postal
#
# -
# Input sentence: postl
# Decoded sentence: postal
#
# -
# Input sentence: posta
# Decoded sentence: postal
#
# -
# Input sentence: pstal
# Decoded sentence: postal
#
# -
# Input sentence: pstladdrss
# Decoded sentence: postal address
#
# -
# Input sentence: postladdrss
# Decoded sentence: postal address
#
# -
# Input sentence: postaaddrss
# Decoded sentence: postal address
#
# -
# Input sentence: pstaladdrss
# Decoded sentence: postal address
#
# -
# Input sentence: pstladrss
# Decoded sentence: postal address
